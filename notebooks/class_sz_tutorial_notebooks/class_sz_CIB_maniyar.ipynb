# %% [markdown]
# # Initialize

# %%
# import necessary modules
# uncomment to get plots displayed in notebook
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy_sz import Class
import math
# Out:
# Metal device set to: Apple M1 Pro
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# 2023-03-23 01:47:10.650661: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-23 01:47:10.650786: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import classy_sz
classy_sz.__file__
# Out:
# '/Users/boris/opt/miniconda3/lib/python3.9/site-packages/classy_sz-2.9.4-py3.9-macosx-11.0-arm64.egg/classy_sz.cpython-39-darwin.so'

# %%
font = {'size'   : 16, 'family':'STIXGeneral'}
axislabelfontsize='large'
matplotlib.rc('font', **font)
plt.rcParams["figure.figsize"] = [8.0,8.0]


# a simple conversion from cl's to dl's
def l_to_dl(lp):
    return lp*(lp+1.)/2./np.pi

# %%
import os
os.chdir('../../class_sz_auxiliary_files/maniyar_cib_benchmark/')

# %%
from headers_constants import *
from Cell_cib import *
from Cell_tSZ import *
from Cell_CIBxtSZ import *
from plot_cell import *
from input_var import *
# Out:
# computing class_sz:
# finnished class_sz hmf computation
# len logmasses in msun: 140
# [1.76387527e+01 1.58617647e+01 1.42600750e+01 1.28368737e+01
#  1.15522029e+01 1.03974392e+01 9.35961024e+00 8.41965053e+00
#  7.57625589e+00 6.81663405e+00 6.13076240e+00 5.51977140e+00
#  4.96721803e+00 4.47044068e+00 4.02398720e+00 3.62000449e+00
#  3.25907781e+00 2.93326121e+00 2.63958335e+00 2.37664262e+00
#  2.13869919e+00 1.92528343e+00 1.73334343e+00 1.55950141e+00
#  1.40453799e+00 1.26434722e+00 1.13792945e+00 1.02474904e+00
#  9.22294989e-01 8.30448025e-01 7.47746611e-01 6.72940882e-01
#  6.06082440e-01 5.45580441e-01 4.91123971e-01 4.42278646e-01
#  3.98015570e-01 3.58447602e-01 3.22713657e-01 2.90385226e-01
#  2.61535865e-01 2.35395028e-01 2.11883790e-01 1.90773458e-01
#  1.71640669e-01 1.54537257e-01 1.39087100e-01 1.25119443e-01
#  1.12643295e-01 1.01328434e-01 9.11751602e-02 8.20400661e-02
#  7.37653851e-02 6.63769398e-02 5.96888089e-02 5.36565467e-02
#  4.82594019e-02 4.33649511e-02 3.89838429e-02 3.50356742e-02
#  3.14553429e-02 2.82706059e-02 2.53845585e-02 2.27851880e-02
#  2.04576092e-02 1.83480658e-02 1.64630765e-02 1.47636817e-02
#  1.32283744e-02 1.18585574e-02 1.06183622e-02 9.50618284e-03
#  8.50911661e-03 7.60605366e-03 6.80285052e-03 6.07794252e-03
#  5.42429710e-03 4.84292545e-03 4.31724163e-03 3.84706344e-03
#  3.42625827e-03 3.04649032e-03 2.70924272e-03 2.40569816e-03
#  2.13334290e-03 1.89156699e-03 1.67366938e-03 1.48016353e-03
#  1.30714842e-03 1.15192113e-03 1.01492763e-03 8.92160136e-04
#  7.82861157e-04 6.86217959e-04 5.99771683e-04 5.23720368e-04
#  4.56205308e-04 3.96145060e-04 3.43678140e-04 2.97109388e-04
#  2.56199633e-04 2.20382518e-04 1.88798054e-04 1.61383298e-04
#  1.37395470e-04 1.16489917e-04 9.84627302e-05 8.27920178e-05
#  6.93320865e-05 5.77878902e-05 4.78646819e-05 3.94847771e-05
#  3.23531258e-05 2.63306260e-05 2.13065169e-05 1.70988870e-05
#  1.36226709e-05 1.07635390e-05 8.42190382e-06 6.53458901e-06
#  5.01428192e-06 3.80515204e-06 2.85527347e-06 2.11375648e-06
#  1.54493429e-06 1.11218496e-06 7.87707827e-07 5.49013352e-07
#  3.75536639e-07 2.51853059e-07 1.65412802e-07 1.06113803e-07
#  6.64557519e-08 4.05227798e-08 2.39994259e-08 1.37841808e-08
#  7.65371039e-09 4.09915941e-09 2.11034050e-09 1.04149507e-09]

# %%
Planck = {'name': 'Planck',
          'do_cib': 1, 'do_tsz': 1, 'do_cibxtsz': 1,
          'freq_cib': [100., 143., 217., 353., 545., 857.],
          'cc': np.array([1.076, 1.017, 1.119, 1.097, 1.068, 0.995, 0.960]),
          'cc_cibmean': np.array([1.076, 1.017, 1.119, 1.097, 1.068, 0.995, 0.960]),
          'freq_cibmean': np.array([100., 143., 217., 353., 545., 857.]),
          'fc': np.ones(7),
          }
exp = Planck
ell = np.geomspace(10., 5e4, 500)
redshifts = np.loadtxt('data_files/redshifts.txt')
z1 = np.linspace(min(redshifts), max(redshifts), 200)
z = redshifts  # z1  # redshifts

logmass = np.arange(8., 15.00, 0.05)

print('len logmass',len(logmass))
mass = 10**logmass

driver = data_var(exp, mass, z, ell)
# Out:
# len logmass 140
# self.Meffmax, self.etamax, self.sigmaMh, self.tau 5343720687478.39 0.5125729451033255 1.2483363577298514 0.82547528668862
# Calculating the halo mass function, halo bias, nfw profile for given mass and redshift for CIB calculations.
# ---------  computing stuuff at z =  0.012
# (140, 500, 210)
# ---------  computing stuuff at z =  0.023
# (140, 500, 210)
# ---------  computing stuuff at z =  0.035
# (140, 500, 210)
# ---------  computing stuuff at z =  0.047
# (140, 500, 210)
# ---------  computing stuuff at z =  0.059
# (140, 500, 210)
# ---------  computing stuuff at z =  0.072
# (140, 500, 210)
# ---------  computing stuuff at z =  0.084
# (140, 500, 210)
# ---------  computing stuuff at z =  0.096
# (140, 500, 210)
# ---------  computing stuuff at z =  0.109
# (140, 500, 210)
# ---------  computing stuuff at z =  0.122
# (140, 500, 210)
# ---------  computing stuuff at z =  0.135
# (140, 500, 210)
# ---------  computing stuuff at z =  0.148
# (140, 500, 210)
# ---------  computing stuuff at z =  0.161
# (140, 500, 210)
# ---------  computing stuuff at z =  0.175
# (140, 500, 210)
# ---------  computing stuuff at z =  0.189
# (140, 500, 210)
# ---------  computing stuuff at z =  0.202
# (140, 500, 210)
# ---------  computing stuuff at z =  0.216
# (140, 500, 210)
# ---------  computing stuuff at z =  0.23
# (140, 500, 210)
# ---------  computing stuuff at z =  0.245
# (140, 500, 210)
# ---------  computing stuuff at z =  0.259
# (140, 500, 210)
# ---------  computing stuuff at z =  0.274
# (140, 500, 210)
# ---------  computing stuuff at z =  0.288
# (140, 500, 210)
# ---------  computing stuuff at z =  0.303
# (140, 500, 210)
# ---------  computing stuuff at z =  0.318
# (140, 500, 210)
# ---------  computing stuuff at z =  0.334
# (140, 500, 210)
# ---------  computing stuuff at z =  0.349
# (140, 500, 210)
# ---------  computing stuuff at z =  0.365
# (140, 500, 210)
# ---------  computing stuuff at z =  0.38
# (140, 500, 210)
# ---------  computing stuuff at z =  0.396
# (140, 500, 210)
# ---------  computing stuuff at z =  0.413
# (140, 500, 210)
# ---------  computing stuuff at z =  0.429
# (140, 500, 210)
# ---------  computing stuuff at z =  0.445
# (140, 500, 210)
# ---------  computing stuuff at z =  0.462
# (140, 500, 210)
# ---------  computing stuuff at z =  0.479
# (140, 500, 210)
# ---------  computing stuuff at z =  0.496
# (140, 500, 210)
# ---------  computing stuuff at z =  0.514
# (140, 500, 210)
# ---------  computing stuuff at z =  0.531
# (140, 500, 210)
# ---------  computing stuuff at z =  0.549
# (140, 500, 210)
# ---------  computing stuuff at z =  0.567
# (140, 500, 210)
# ---------  computing stuuff at z =  0.585
# (140, 500, 210)
# ---------  computing stuuff at z =  0.603
# (140, 500, 210)
# ---------  computing stuuff at z =  0.622
# (140, 500, 210)
# ---------  computing stuuff at z =  0.641
# (140, 500, 210)
# ---------  computing stuuff at z =  0.66
# (140, 500, 210)
# ---------  computing stuuff at z =  0.679
# (140, 500, 210)
# ---------  computing stuuff at z =  0.698
# (140, 500, 210)
# ---------  computing stuuff at z =  0.718
# (140, 500, 210)
# ---------  computing stuuff at z =  0.738
# (140, 500, 210)
# ---------  computing stuuff at z =  0.758
# (140, 500, 210)
# ---------  computing stuuff at z =  0.778
# (140, 500, 210)
# ---------  computing stuuff at z =  0.799
# (140, 500, 210)
# ---------  computing stuuff at z =  0.82
# (140, 500, 210)
# ---------  computing stuuff at z =  0.841
# (140, 500, 210)
# ---------  computing stuuff at z =  0.862
# (140, 500, 210)
# ---------  computing stuuff at z =  0.884
# (140, 500, 210)
# ---------  computing stuuff at z =  0.905
# (140, 500, 210)
# ---------  computing stuuff at z =  0.928
# (140, 500, 210)
# ---------  computing stuuff at z =  0.95
# (140, 500, 210)
# ---------  computing stuuff at z =  0.972
# (140, 500, 210)
# ---------  computing stuuff at z =  0.995
# (140, 500, 210)
# ---------  computing stuuff at z =  1.018
# (140, 500, 210)
# ---------  computing stuuff at z =  1.042
# (140, 500, 210)
# ---------  computing stuuff at z =  1.065
# (140, 500, 210)
# ---------  computing stuuff at z =  1.089
# (140, 500, 210)
# ---------  computing stuuff at z =  1.113
# (140, 500, 210)
# ---------  computing stuuff at z =  1.138
# (140, 500, 210)
# ---------  computing stuuff at z =  1.163
# (140, 500, 210)
# ---------  computing stuuff at z =  1.188
# (140, 500, 210)
# ---------  computing stuuff at z =  1.213
# (140, 500, 210)
# ---------  computing stuuff at z =  1.239
# (140, 500, 210)
# ---------  computing stuuff at z =  1.265
# (140, 500, 210)
# ---------  computing stuuff at z =  1.291
# (140, 500, 210)
# ---------  computing stuuff at z =  1.317
# (140, 500, 210)
# ---------  computing stuuff at z =  1.344
# (140, 500, 210)
# ---------  computing stuuff at z =  1.371
# (140, 500, 210)
# ---------  computing stuuff at z =  1.399
# (140, 500, 210)
# ---------  computing stuuff at z =  1.427
# (140, 500, 210)
# ---------  computing stuuff at z =  1.455
# (140, 500, 210)
# ---------  computing stuuff at z =  1.483
# (140, 500, 210)
# ---------  computing stuuff at z =  1.512
# (140, 500, 210)
# ---------  computing stuuff at z =  1.541
# (140, 500, 210)
# ---------  computing stuuff at z =  1.57
# (140, 500, 210)
# ---------  computing stuuff at z =  1.6
# (140, 500, 210)
# ---------  computing stuuff at z =  1.63
# (140, 500, 210)
# ---------  computing stuuff at z =  1.661
# (140, 500, 210)
# ---------  computing stuuff at z =  1.692
# (140, 500, 210)
# ---------  computing stuuff at z =  1.723
# (140, 500, 210)
# ---------  computing stuuff at z =  1.754
# (140, 500, 210)
# ---------  computing stuuff at z =  1.786
# (140, 500, 210)
# ---------  computing stuuff at z =  1.818
# (140, 500, 210)
# ---------  computing stuuff at z =  1.851
# (140, 500, 210)
# ---------  computing stuuff at z =  1.884
# (140, 500, 210)
# ---------  computing stuuff at z =  1.917
# (140, 500, 210)
# ---------  computing stuuff at z =  1.951
# (140, 500, 210)
# ---------  computing stuuff at z =  1.985
# (140, 500, 210)
# ---------  computing stuuff at z =  2.02
# (140, 500, 210)
# ---------  computing stuuff at z =  2.055
# (140, 500, 210)
# ---------  computing stuuff at z =  2.09
# (140, 500, 210)
# ---------  computing stuuff at z =  2.126
# (140, 500, 210)
# ---------  computing stuuff at z =  2.162
# (140, 500, 210)
# ---------  computing stuuff at z =  2.199
# (140, 500, 210)
# ---------  computing stuuff at z =  2.236
# (140, 500, 210)
# ---------  computing stuuff at z =  2.273
# (140, 500, 210)
# ---------  computing stuuff at z =  2.311
# (140, 500, 210)
# ---------  computing stuuff at z =  2.35
# (140, 500, 210)
# ---------  computing stuuff at z =  2.388
# (140, 500, 210)
# ---------  computing stuuff at z =  2.428
# (140, 500, 210)
# ---------  computing stuuff at z =  2.467
# (140, 500, 210)
# ---------  computing stuuff at z =  2.508
# (140, 500, 210)
# ---------  computing stuuff at z =  2.548
# (140, 500, 210)
# ---------  computing stuuff at z =  2.589
# (140, 500, 210)
# ---------  computing stuuff at z =  2.631
# (140, 500, 210)
# ---------  computing stuuff at z =  2.673
# (140, 500, 210)
# ---------  computing stuuff at z =  2.715
# (140, 500, 210)
# ---------  computing stuuff at z =  2.758
# (140, 500, 210)
# ---------  computing stuuff at z =  2.802
# (140, 500, 210)
# ---------  computing stuuff at z =  2.846
# (140, 500, 210)
# ---------  computing stuuff at z =  2.89
# (140, 500, 210)
# ---------  computing stuuff at z =  2.936
# (140, 500, 210)
# ---------  computing stuuff at z =  2.981
# (140, 500, 210)
# ---------  computing stuuff at z =  3.027
# (140, 500, 210)
# ---------  computing stuuff at z =  3.074
# (140, 500, 210)
# ---------  computing stuuff at z =  3.121
# (140, 500, 210)
# ---------  computing stuuff at z =  3.169
# (140, 500, 210)
# ---------  computing stuuff at z =  3.217
# (140, 500, 210)
# ---------  computing stuuff at z =  3.266
# (140, 500, 210)
# ---------  computing stuuff at z =  3.315
# (140, 500, 210)
# ---------  computing stuuff at z =  3.365
# (140, 500, 210)
# ---------  computing stuuff at z =  3.416
# (140, 500, 210)
# ---------  computing stuuff at z =  3.467
# (140, 500, 210)
# ---------  computing stuuff at z =  3.519
# (140, 500, 210)
# ---------  computing stuuff at z =  3.571
# (140, 500, 210)
# ---------  computing stuuff at z =  3.624
# (140, 500, 210)
# ---------  computing stuuff at z =  3.677
# (140, 500, 210)
# ---------  computing stuuff at z =  3.732
# (140, 500, 210)
# ---------  computing stuuff at z =  3.786
# (140, 500, 210)
# ---------  computing stuuff at z =  3.842
# (140, 500, 210)
# ---------  computing stuuff at z =  3.898
# (140, 500, 210)
# ---------  computing stuuff at z =  3.955
# (140, 500, 210)
# ---------  computing stuuff at z =  4.012
# (140, 500, 210)
# ---------  computing stuuff at z =  4.07
# (140, 500, 210)
# ---------  computing stuuff at z =  4.129
# (140, 500, 210)
# ---------  computing stuuff at z =  4.188
# (140, 500, 210)
# ---------  computing stuuff at z =  4.248
# (140, 500, 210)
# ---------  computing stuuff at z =  4.309
# (140, 500, 210)
# ---------  computing stuuff at z =  4.37
# (140, 500, 210)
# ---------  computing stuuff at z =  4.433
# (140, 500, 210)
# ---------  computing stuuff at z =  4.495
# (140, 500, 210)
# ---------  computing stuuff at z =  4.559
# (140, 500, 210)
# ---------  computing stuuff at z =  4.623
# (140, 500, 210)
# ---------  computing stuuff at z =  4.689
# (140, 500, 210)
# ---------  computing stuuff at z =  4.754
# (140, 500, 210)
# ---------  computing stuuff at z =  4.821
# (140, 500, 210)
# ---------  computing stuuff at z =  4.888
# (140, 500, 210)
# ---------  computing stuuff at z =  4.957
# (140, 500, 210)
# ---------  computing stuuff at z =  5.026
# (140, 500, 210)
# ---------  computing stuuff at z =  5.095
# (140, 500, 210)
# ---------  computing stuuff at z =  5.166
# (140, 500, 210)
# ---------  computing stuuff at z =  5.237
# (140, 500, 210)
# ---------  computing stuuff at z =  5.31
# (140, 500, 210)
# ---------  computing stuuff at z =  5.383
# (140, 500, 210)
# ---------  computing stuuff at z =  5.457
# (140, 500, 210)
# ---------  computing stuuff at z =  5.531
# (140, 500, 210)
# ---------  computing stuuff at z =  5.607
# (140, 500, 210)
# ---------  computing stuuff at z =  5.683
# (140, 500, 210)
# ---------  computing stuuff at z =  5.761
# (140, 500, 210)
# ---------  computing stuuff at z =  5.839
# (140, 500, 210)
# ---------  computing stuuff at z =  5.918
# (140, 500, 210)
# ---------  computing stuuff at z =  5.998
# (140, 500, 210)
# ---------  computing stuuff at z =  6.079
# (140, 500, 210)
# ---------  computing stuuff at z =  6.161
# (140, 500, 210)
# ---------  computing stuuff at z =  6.244
# (140, 500, 210)
# ---------  computing stuuff at z =  6.328
# (140, 500, 210)
# ---------  computing stuuff at z =  6.413
# (140, 500, 210)
# ---------  computing stuuff at z =  6.499
# (140, 500, 210)
# ---------  computing stuuff at z =  6.586
# (140, 500, 210)
# ---------  computing stuuff at z =  6.674
# (140, 500, 210)
# ---------  computing stuuff at z =  6.762
# (140, 500, 210)
# ---------  computing stuuff at z =  6.852
# (140, 500, 210)
# ---------  computing stuuff at z =  6.943
# (140, 500, 210)
# ---------  computing stuuff at z =  7.035
# (140, 500, 210)
# ---------  computing stuuff at z =  7.128
# (140, 500, 210)
# ---------  computing stuuff at z =  7.222
# (140, 500, 210)
# ---------  computing stuuff at z =  7.318
# (140, 500, 210)
# ---------  computing stuuff at z =  7.414
# (140, 500, 210)
# ---------  computing stuuff at z =  7.511
# (140, 500, 210)
# ---------  computing stuuff at z =  7.61
# (140, 500, 210)
# ---------  computing stuuff at z =  7.71
# (140, 500, 210)
# ---------  computing stuuff at z =  7.81
# (140, 500, 210)
# ---------  computing stuuff at z =  7.913
# (140, 500, 210)
# ---------  computing stuuff at z =  8.016
# (140, 500, 210)
# ---------  computing stuuff at z =  8.12
# (140, 500, 210)
# ---------  computing stuuff at z =  8.226
# (140, 500, 210)
# ---------  computing stuuff at z =  8.333
# (140, 500, 210)
# ---------  computing stuuff at z =  8.441
# (140, 500, 210)
# ---------  computing stuuff at z =  8.55
# (140, 500, 210)
# ---------  computing stuuff at z =  8.661
# (140, 500, 210)
# ---------  computing stuuff at z =  8.772
# (140, 500, 210)
# ---------  computing stuuff at z =  8.886
# (140, 500, 210)
# ---------  computing stuuff at z =  9.0
# (140, 500, 210)
# ---------  computing stuuff at z =  9.116
# (140, 500, 210)
# ---------  computing stuuff at z =  9.233
# (140, 500, 210)
# ---------  computing stuuff at z =  9.351
# (140, 500, 210)
# ---------  computing stuuff at z =  9.471
# (140, 500, 210)
# ---------  computing stuuff at z =  9.593
# (140, 500, 210)
# ---------  computing stuuff at z =  9.715
# (140, 500, 210)
# ---------  computing stuuff at z =  9.839
# (140, 500, 210)
# ---------  computing stuuff at z =  9.965
# (140, 500, 210)
# ---------  computing stuuff at z =  10.092
# (140, 500, 210)
# ---------  computing stuuff at z =  10.22
# (140, 500, 210)
# Calculating the halo mass function, halo bias, nfw profile for given mass and redshift for tSZ calculations.

# %%
clcib = cl_cib(driver)
cl1h_cib = clcib.onehalo_int()
cl2h_cib = clcib.twohalo_int()
# Out:
# etamax and Meffmax
# 0.5125729451033255 5343720687478.39
# color correction in 1halo: [1. 1. 1. 1. 1. 1.]
# us in one halo [[[9.99999830e-01 9.99999953e-01 9.99999979e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999824e-01 9.99999951e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999818e-01 9.99999949e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.81386359e-01 3.87286993e-01 6.28837354e-01 ... 9.99742179e-01
#    9.99743643e-01 9.99745081e-01]
#   [1.77821347e-01 3.77696488e-01 6.19428293e-01 ... 9.99733228e-01
#    9.99734742e-01 9.99736230e-01]
#   [1.74114782e-01 3.68272419e-01 6.09895285e-01 ... 9.99723965e-01
#    9.99725532e-01 9.99727071e-01]]
#
#  [[9.99999816e-01 9.99999949e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999810e-01 9.99999947e-01 9.99999977e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999803e-01 9.99999945e-01 9.99999976e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.73171881e-01 3.65959350e-01 6.07508998e-01 ... 9.99721615e-01
#    9.99723195e-01 9.99724748e-01]
#   [1.69286424e-01 3.56764889e-01 5.97829645e-01 ... 9.99711949e-01
#    9.99713584e-01 9.99715191e-01]
#   [1.65262316e-01 3.47771367e-01 5.88040466e-01 ... 9.99701948e-01
#    9.99703640e-01 9.99705302e-01]]
#
#  [[9.99999802e-01 9.99999945e-01 9.99999976e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999795e-01 9.99999943e-01 9.99999975e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999788e-01 9.99999941e-01 9.99999974e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.64242381e-01 3.45570471e-01 5.85592891e-01 ... 9.99699411e-01
#    9.99701117e-01 9.99702793e-01]
#   [1.60059849e-01 3.36848148e-01 5.75676797e-01 ... 9.99688974e-01
#    9.99690740e-01 9.99692474e-01]
#   [1.55768741e-01 3.28358521e-01 5.65667921e-01 ... 9.99678175e-01
#    9.99680002e-01 9.99681797e-01]]
#
#  ...
#
#  [[9.93752136e-01 9.98260610e-01 9.99232210e-01 ... 9.99999593e-01
#    9.99999595e-01 9.99999597e-01]
#   [9.93535974e-01 9.98200269e-01 9.99205559e-01 ... 9.99999579e-01
#    9.99999581e-01 9.99999583e-01]
#   [9.93312362e-01 9.98137838e-01 9.99177984e-01 ... 9.99999564e-01
#    9.99999567e-01 9.99999569e-01]
#   ...
#   [8.59731176e-06 3.05488165e-05 7.19009129e-05 ... 9.15345783e-02
#    9.17950601e-02 9.20547535e-02]
#   [8.24589141e-06 3.12099205e-05 6.69522498e-05 ... 9.00088640e-02
#    9.02601937e-02 9.05094498e-02]
#   [8.19820398e-06 2.85487821e-05 6.75825568e-05 ... 8.85081632e-02
#    8.87588670e-02 8.90061171e-02]]
#
#  [[9.93255638e-01 9.98121999e-01 9.99170988e-01 ... 9.99999560e-01
#    9.99999563e-01 9.99999565e-01]
#   [9.93022368e-01 9.98056855e-01 9.99142214e-01 ... 9.99999545e-01
#    9.99999548e-01 9.99999550e-01]
#   [9.92781062e-01 9.97989454e-01 9.99112441e-01 ... 9.99999529e-01
#    9.99999532e-01 9.99999535e-01]
#   ...
#   [7.88107897e-06 2.94948609e-05 6.43144154e-05 ... 8.81334135e-02
#    8.83852564e-02 8.86332980e-02]
#   [7.68511982e-06 2.81861638e-05 6.32141319e-05 ... 8.65938409e-02
#    8.68551779e-02 8.71113374e-02]
#   [7.41984257e-06 2.65662974e-05 6.32252865e-05 ... 8.49720402e-02
#    8.52499338e-02 8.55213838e-02]]
#
#  [[9.92719851e-01 9.97972355e-01 9.99104887e-01 ... 9.99999525e-01
#    9.99999528e-01 9.99999531e-01]
#   [9.92468130e-01 9.97902026e-01 9.99073820e-01 ... 9.99999509e-01
#    9.99999512e-01 9.99999514e-01]
#   [9.92207744e-01 9.97829262e-01 9.99041675e-01 ... 9.99999492e-01
#    9.99999495e-01 9.99999497e-01]
#   ...
#   [7.32578971e-06 2.76408900e-05 5.93838985e-05 ... 8.45519219e-02
#    8.48348626e-02 8.51110733e-02]
#   [7.20384519e-06 2.60859461e-05 5.87194145e-05 ... 8.27760625e-02
#    8.30822659e-02 8.33807441e-02]
#   [7.16597611e-06 2.44731204e-05 5.83235466e-05 ... 8.08486055e-02
#    8.11812312e-02 8.15054515e-02]]]
# us in two halo [[[9.99999830e-01 9.99999953e-01 9.99999979e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999824e-01 9.99999951e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999818e-01 9.99999949e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.81386359e-01 3.87286993e-01 6.28837354e-01 ... 9.99742179e-01
#    9.99743643e-01 9.99745081e-01]
#   [1.77821347e-01 3.77696488e-01 6.19428293e-01 ... 9.99733228e-01
#    9.99734742e-01 9.99736230e-01]
#   [1.74114782e-01 3.68272419e-01 6.09895285e-01 ... 9.99723965e-01
#    9.99725532e-01 9.99727071e-01]]
#
#  [[9.99999816e-01 9.99999949e-01 9.99999978e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999810e-01 9.99999947e-01 9.99999977e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999803e-01 9.99999945e-01 9.99999976e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.73171881e-01 3.65959350e-01 6.07508998e-01 ... 9.99721615e-01
#    9.99723195e-01 9.99724748e-01]
#   [1.69286424e-01 3.56764889e-01 5.97829645e-01 ... 9.99711949e-01
#    9.99713584e-01 9.99715191e-01]
#   [1.65262316e-01 3.47771367e-01 5.88040466e-01 ... 9.99701948e-01
#    9.99703640e-01 9.99705302e-01]]
#
#  [[9.99999802e-01 9.99999945e-01 9.99999976e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999795e-01 9.99999943e-01 9.99999975e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [9.99999788e-01 9.99999941e-01 9.99999974e-01 ... 1.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   ...
#   [1.64242381e-01 3.45570471e-01 5.85592891e-01 ... 9.99699411e-01
#    9.99701117e-01 9.99702793e-01]
#   [1.60059849e-01 3.36848148e-01 5.75676797e-01 ... 9.99688974e-01
#    9.99690740e-01 9.99692474e-01]
#   [1.55768741e-01 3.28358521e-01 5.65667921e-01 ... 9.99678175e-01
#    9.99680002e-01 9.99681797e-01]]
#
#  ...
#
#  [[9.93752136e-01 9.98260610e-01 9.99232210e-01 ... 9.99999593e-01
#    9.99999595e-01 9.99999597e-01]
#   [9.93535974e-01 9.98200269e-01 9.99205559e-01 ... 9.99999579e-01
#    9.99999581e-01 9.99999583e-01]
#   [9.93312362e-01 9.98137838e-01 9.99177984e-01 ... 9.99999564e-01
#    9.99999567e-01 9.99999569e-01]
#   ...
#   [8.59731176e-06 3.05488165e-05 7.19009129e-05 ... 9.15345783e-02
#    9.17950601e-02 9.20547535e-02]
#   [8.24589141e-06 3.12099205e-05 6.69522498e-05 ... 9.00088640e-02
#    9.02601937e-02 9.05094498e-02]
#   [8.19820398e-06 2.85487821e-05 6.75825568e-05 ... 8.85081632e-02
#    8.87588670e-02 8.90061171e-02]]
#
#  [[9.93255638e-01 9.98121999e-01 9.99170988e-01 ... 9.99999560e-01
#    9.99999563e-01 9.99999565e-01]
#   [9.93022368e-01 9.98056855e-01 9.99142214e-01 ... 9.99999545e-01
#    9.99999548e-01 9.99999550e-01]
#   [9.92781062e-01 9.97989454e-01 9.99112441e-01 ... 9.99999529e-01
#    9.99999532e-01 9.99999535e-01]
#   ...
#   [7.88107897e-06 2.94948609e-05 6.43144154e-05 ... 8.81334135e-02
#    8.83852564e-02 8.86332980e-02]
#   [7.68511982e-06 2.81861638e-05 6.32141319e-05 ... 8.65938409e-02
#    8.68551779e-02 8.71113374e-02]
#   [7.41984257e-06 2.65662974e-05 6.32252865e-05 ... 8.49720402e-02
#    8.52499338e-02 8.55213838e-02]]
#
#  [[9.92719851e-01 9.97972355e-01 9.99104887e-01 ... 9.99999525e-01
#    9.99999528e-01 9.99999531e-01]
#   [9.92468130e-01 9.97902026e-01 9.99073820e-01 ... 9.99999509e-01
#    9.99999512e-01 9.99999514e-01]
#   [9.92207744e-01 9.97829262e-01 9.99041675e-01 ... 9.99999492e-01
#    9.99999495e-01 9.99999497e-01]
#   ...
#   [7.32578971e-06 2.76408900e-05 5.93838985e-05 ... 8.45519219e-02
#    8.48348626e-02 8.51110733e-02]
#   [7.20384519e-06 2.60859461e-05 5.87194145e-05 ... 8.27760625e-02
#    8.30822659e-02 8.33807441e-02]
#   [7.16597611e-06 2.44731204e-05 5.83235466e-05 ... 8.08486055e-02
#    8.11812312e-02 8.15054515e-02]]]
# color correction in 2halo: [1. 1. 1. 1. 1. 1.]

# %%
Omegam0 = 0.3075
H0 = 67.74
Omegab = 0.0486
Omegac = 0.2589
Omegac + Omegab
omega_b = Omegab*(H0/100.)**2
omega_c = Omegac*(H0/100.)**2
hparam = H0/100.
maniyar_cosmo = {
'omega_b': omega_b,
'omega_cdm':  omega_c,
'h': H0/100.,
# 'tau_reio': 0.0561,
'ln10^{10}A_s': 3.048,
'n_s': 0.9665,
# 'sigma8':0.830,
'k_pivot': 0.05,
'N_ncdm': 1,
'N_ur': 2.0328,
'm_ncdm': 0.0
}

# %%
# %%time
M = Class()
M.set({'output':'dndlnM,cib_cib_1h,cib_cib_2h'})
M.set(maniyar_cosmo)
M.set({

'mass function' : 'T08M200c',
'use_maniyar_cib_model':1,

'maniyar_cib_etamax' : 5.12572945e-01,

'maniyar_cib_zc' : 1.5,
'maniyar_cib_tau' : 8.25475287e-01,
'maniyar_cib_fsub' : 0.134*np.log(10.),
'Most efficient halo mass in Msun' : 5.34372069e+12,
'Size of of halo masses sourcing CIB emission' :  1.5583436676980493,
#for the Lsat tabulation:
'freq_min': 9e1,
'freq_max': 8.57e2,
'dlogfreq' : 0.1,

'concentration parameter':'fixed', # this sets it to 5

'n_z_L_sat' :100,
'n_m_L_sat' :100,
'n_nu_L_sat':100,

'use_nc_1_for_all_halos_cib_HOD': 1,

'sub_halo_mass_function' : 'TW10',#'JvdB14',
'M_min_subhalo_in_Msun' : 1e5, # 1e5 see https://github.com/abhimaniyar/halomodel_cib_tsz_cibxtsz/blob/master/Cell_cib.py
'use_redshift_dependent_M_min': 0,
'M_min' : 1e8*hparam,
'M_max' : 1e15*hparam,
'z_min' : 0.012,
'z_max' : 10.,
'ell_min': 10.,
'ell_max':5e4,
'dlogell':0.3,


'ndim_redshifts': 210,
'ndim_masses':150,

'has_cib_flux_cut': 0,
'hm_consistency':0,

'epsabs_L_sat': 1e-40,
'epsrel_L_sat': 1e-9,

# "P_k_max_1/Mpc": 50.,
# 'k_max_for_pk_class_sz':50.
})

M.set({
       'cib_frequency_list_num' : 6,
       'cib_frequency_list_in_GHz' : '100,143,217,353,545,857',
      })
M.compute()

# %%
from matplotlib.lines import Line2D
cl_cib_cib = M.cl_cib_cib()
freq = ['100', '143', '217', '353', '545', '857']
# freq = ['545']
# nu1, nu2 = 4, 4
# plot_Cell(ell, cl1h_cib, cl2h_cib, nu1, nu2, freq, 'CIB')
two_halo = cl2h_cib
one_halo = cl1h_cib
faccib = 1.

# plot_dim = int(1/2*(-1 + np.sqrt(1 + 8*len(freq))))
plot_dim = len(freq)
fig, axes = plt.subplots(figsize=(19, 19),
                         sharex=True,
                         #sharey=True,
                         ncols=plot_dim,
                         nrows=plot_dim)

plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.0,
                    hspace=0.0)

for i in range(plot_dim):
    for j in range(plot_dim):
        if i==0 and j==(plot_dim-1):
            ax = axes[i, j]
            custom_lines = [Line2D([0], [0], color='k', lw=2,ls='-.'),
                            Line2D([0], [0], color='k', lw=2,ls='-'),
                            Line2D([0], [0], color='b', lw=1,ls='-.'),
                            Line2D([0], [0], color='b', lw=1,ls='-')]
            ax.legend(custom_lines, ['CLASS_SZ 1h', 'CLASS_SZ 2h', 'Maniyar et al 1h','Maniyar et al 2h'],
                      fontsize=18,frameon=False)
            # ax.legend()
            ax.axis('off')
        elif i<j:
            axes[i, j].axis('off')
        else:
            ax = axes[i, j]
            freqs = freq[i]
            freqsp = freq[j]
            nu1 = i
            nu2 = j
            faccib = Planck['cc'][i]*Planck['cc'][j]
            # ax.set_title(freqs+'x'+freqsp,size=9)
            if j==0:
                # ax.set_ylabel(r'$\mathrm{C_l}\: [\mathrm{Jy}^2\: \mathrm{sr}^{-1}]$', fontsize=12)
                ax.set_ylabel(freqs, fontsize=12)
            if i==(plot_dim-1):
                # ax.set_xlabel(r'$\;\ell$', fontsize=12)
                ax.set_xlabel(freqsp, fontsize=12)
            ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
            ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)
            ax.xaxis.set_ticks_position('both')
            ax.yaxis.set_ticks_position('both')
            plt.setp(ax.get_yticklabels(), rotation='horizontal', fontsize=12)
            plt.setp(ax.get_xticklabels(), fontsize=12)
            ax.grid( visible=True, which="both", alpha=0.2, linestyle='--')
            ax.plot(ell, np.abs(one_halo[nu1, nu2, :])*faccib, 'b-.', label='Maniyar et al 1h',lw=0.6)
            ax.plot(ell, np.abs(two_halo[nu1, nu2, :])*faccib, 'b-', label='Maniyar et al 2h',lw=0.6)
            # ax.plot(ell, np.abs(total[nu1, nu2, :]), 'b', label='total')
            l = np.asarray(cl_cib_cib[freqs+'x'+freqs]['ell'])
            ax.plot(l,cl_cib_cib[freqs+'x'+freqsp]['1h']/l_to_dl(l)*faccib+cl_cib_cib[freqs+'x'+freqsp]['2h']/l_to_dl(l)*faccib*0.,ls='-.',c='k',label='class_sz 1h ')
            ax.plot(l,cl_cib_cib[freqs+'x'+freqsp]['1h']/l_to_dl(l)*faccib*0.+cl_cib_cib[freqs+'x'+freqsp]['2h']/l_to_dl(l)*faccib,ls='-',c='k',label='class_sz 2h ')
            ax.set_xscale("log")
            ax.set_yscale("log")
            ax.set_xlim(20,50000)
            if freqs=='100' and freqsp=='100':
                ax.set_ylim(5e-3,5)
            if freqs=='143' and freqsp=='100':
                ax.set_ylim(1e-2,2e1)
            if freqs=='217' and freqsp=='100':
                ax.set_ylim(1e-1,5e1)
            if freqs=='353' and freqsp=='100':
                ax.set_ylim(1e-1,3e2)
            if freqs=='545' and freqsp=='100':
                ax.set_ylim(1e0,6e2)
            if freqs=='857' and freqsp=='100':
                ax.set_ylim(1e0,2e3)
                
            if freqs=='143' and freqsp=='143':
                ax.set_ylim(1e-1,7e1)
            if freqs=='217' and freqsp=='143':
                ax.set_ylim(5e-1,2e2)
            if freqs=='353' and freqsp=='143':
                ax.set_ylim(2e0,6e2)
            if freqs=='545' and freqsp=='143':
                ax.set_ylim(7e0,2e3)
            if freqs=='857' and freqsp=='143':
                ax.set_ylim(1e1,5e3)
                

            if freqs=='217' and freqsp=='217':
                ax.set_ylim(5e-1,2e3)
            if freqs=='353' and freqsp=='217':
                ax.set_ylim(2e0,6e3)
            if freqs=='545' and freqsp=='217':
                ax.set_ylim(7e0,2e4)
            if freqs=='857' and freqsp=='217':
                ax.set_ylim(1e1,5e4)


            if freqs=='353' and freqsp=='353':
                ax.set_ylim(2e1,1e4)
            if freqs=='545' and freqsp=='353':
                ax.set_ylim(7e1,2e5)
            if freqs=='857' and freqsp=='353':
                ax.set_ylim(1e2,5e5)
                
            if freqs=='545' and freqsp=='545':
                ax.set_ylim(7e1,2e5)
            if freqs=='857' and freqsp=='545':
                ax.set_ylim(1e2,5e5)
                
            if freqs=='857' and freqsp=='857':
                ax.set_ylim(1e2,5e5)
fig.suptitle('CIB Power Spectra at the Planck Frequencies',fontsize=20)
fig.tight_layout()

plt.savefig('../../notebooks/class_sz_tutorial_notebooks/figures/maniyar_benchmark.pdf')
